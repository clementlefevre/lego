# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import numpy as np
import itertools
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-f2503d55da1d> in <module>()
# ----> 1 get_ipython().magic(u'matplotlib inline')
#       2 import matplotlib.pyplot as plt
#       3 import pandas as pd
#       4 import pickle
#       5 import numpy as np
#
# /Users/clement/anaconda/envs/py27/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in magic(self, arg_s)
#    2158         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2159         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2160         return self.run_line_magic(magic_name, magic_arg_s)
#    2161
#    2162     #-------------------------------------------------------------------------
#
# /Users/clement/anaconda/envs/py27/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_line_magic(self, magic_name, line)
#    2079                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2080             with self.builtin_trap:
# -> 2081                 result = fn(*args,**kwargs)
#    2082             return result
#    2083
#
# <decorator-gen-105> in matplotlib(self, line)
#
# /Users/clement/anaconda/envs/py27/lib/python2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /Users/clement/anaconda/envs/py27/lib/python2.7/site-packages/IPython/core/magics/pylab.pyc in matplotlib(self, line)
#      98             print("Available matplotlib backends: %s" % backends_list)
#      99         else:
# --> 100             gui, backend = self.shell.enable_matplotlib(args.gui)
#     101             self._show_matplotlib_backend(args.gui, backend)
#     102
#
# /Users/clement/anaconda/envs/py27/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in enable_matplotlib(self, gui)
#    2936         """
#    2937         from IPython.core import pylabtools as pt
# -> 2938         gui, backend = pt.find_gui_and_backend(gui, self.pylab_gui_select)
#    2939
#    2940         if gui != 'inline':
#
# /Users/clement/anaconda/envs/py27/lib/python2.7/site-packages/IPython/core/pylabtools.pyc in find_gui_and_backend(gui, gui_select)
#     271     """
#     272
# --> 273     import matplotlib
#     274
#     275     if gui and gui != 'auto':
#
# ImportError: No module named matplotlib

# %%
df_parts = pd.read_csv('data/parts.csv')
df_parts_categories = pd.read_csv('data/part_categories.csv')
df_inventories = pd.read_csv('data/inventories.csv')
df_inventories_parts = pd.read_csv('data/inventory_parts.csv')
df_sets = pd.read_csv('data/sets.csv')

df_sets.head()

df_PARTS = pd.merge(df_parts,df_parts_categories,left_on='part_cat_id',right_on='id',how='left',suffixes=['_part','_cat'])

df_PARTS.head()

df_SETS = pd.merge(df_inventories_parts,df_inventories,left_on='inventory_id',right_on='id',how='left')
df_SETS = pd.merge(df_SETS,df_sets,on='set_num',how='left')
df_SETS = pd.merge(df_SETS,df_PARTS[['part_num','name_part','name_cat']],on='part_num',how='left')
df_SETS.head()

# %% [markdown]
# ### Drop the figurines from castle

# %%
df_6075_2_BOM = df_SETS[df_SETS.set_num=='6075-2']
df_6075_2_BOM.groupby('name_cat').count()
print df_6075_2_BOM.name_cat.unique()
CATEGORIES_TO_EXCLUDE = ['Flags, Signs, Plastics and Cloth','Minifigs','Minifig Accessories']
# Out:
# ['Bricks' 'Plates' 'Bricks Sloped' 'Bricks Round and Cones' 'Tiles'
#  'Windows and Doors' 'Plates Special' 'Bars, Ladders and Fences'
#  'Bricks Curved' 'Bricks Special' 'Flags, Signs, Plastics and Cloth'
#  'Minifigs' 'Technic Pins' 'Technic Bricks' 'Hinges, Arms and Turntables'
#  'Minifig Accessories' 'Baseplates' 'String, Bands and Reels']

# %% [markdown]
# ## Aggregate all colors quantities

# %%
df_6075_2_BOM = df_SETS[df_SETS.set_num=='6075-2']
df_6075_2_BOM = df_6075_2_BOM[~df_6075_2_BOM.name_cat.isin(CATEGORIES_TO_EXCLUDE)]
df_6075_2_BOM = df_6075_2_BOM.groupby(['part_num'])[['quantity']].sum().reset_index()
print df_6075_2_BOM.info()
print df_6075_2_BOM.quantity.sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 2 columns):
# part_num    45 non-null object
# quantity    45 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 792.0+ bytes
# None
# 676

# %%
df_SETS_BOM= df_SETS.groupby(['set_num','part_num','name'])[['quantity']].sum()

# %%
df_SETS_BOM.reset_index(inplace=True)
df_SETS_BOM.head()
# Out:
#    index set_num part_num             name  quantity
# 0      0    00-1    29c01  Weetabix Castle        14
# 1      1    00-1    3001a  Weetabix Castle        38
# 2      2    00-1    3002a  Weetabix Castle        22
# 3      3    00-1     3003  Weetabix Castle        12
# 4      4    00-1     3004  Weetabix Castle       115

# %%
df_BOM_SETS = df_SETS_BOM.pivot(index='set_num', columns='part_num', values='quantity')

# %%
df_BOM_SETS = df_BOM_SETS.fillna(0)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler() 
scaled_values = scaler.fit_transform(df_BOM_SETS) 
df_BOM_SETS.loc[:,:] = scaled_values

# %%
len(df_SETS_BOM.set_num.unique())
df_SETS_modern = df_SETS[df_SETS.year>2008]
sets_modern = df_SETS_modern.groupby('set_num').agg({'part_num':['count'],'quantity':['sum']})
sets_modern.describe()
# Out:
#           part_num     quantity
#              count          sum
# count  4337.000000  4337.000000
# mean     70.284528   221.350473
# std      83.583060   410.179967
# min       1.000000     1.000000
# 25%      12.000000    18.000000
# 50%      37.000000    69.000000
# 75%     101.000000   251.000000
# max     769.000000  5200.000000

# %%
df_BOMs = pd.DataFrame()
i=0
for name,group in df_SETS_BOM.groupby('set_num'):
    df = pd.merge(df_6075_2_BOM,group, on='part_num', how='inner',suffixes=['_6075_2','_sets'])
    
    df['Set']=name
    df_BOMs = pd.concat([df_BOMs,df],axis=0)
    i+=1
    if i%1000==0:
        print i
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000

# %%
df_BOMs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 69308 entries, 0 to 1
# Data columns (total 6 columns):
# part_num           69308 non-null object
# quantity_6075_2    69308 non-null int64
# set_num            69308 non-null object
# name               69308 non-null object
# quantity_sets      69308 non-null int64
# Set                69308 non-null object
# dtypes: int64(2), object(4)
# memory usage: 3.7+ MB

# %%
df_BOMs.head()
# Out:
#   part_num  quantity_6075_2 set_num             name  quantity_sets   Set
# 0    3002a               12    00-1  Weetabix Castle             22  00-1
# 1     3003               16    00-1  Weetabix Castle             12  00-1
# 2     3004              195    00-1  Weetabix Castle            115  00-1
# 3     3005               73    00-1  Weetabix Castle             57  00-1
# 4     3008               15    00-1  Weetabix Castle             18  00-1

# %%
df_BOMs['Filled_Quantity']=df_BOMs.quantity_6075_2-df_BOMs.quantity_sets
df_BOMs.Filled_Quantity = np.where(df_BOMs.Filled_Quantity<0,df_BOMs.quantity_6075_2,df_BOMs.quantity_sets)

# %%
df_BOMs.head()
# Out:
#   part_num  quantity_6075_2 set_num             name  quantity_sets   Set  \
# 0    3002a               12    00-1  Weetabix Castle             22  00-1
# 1     3003               16    00-1  Weetabix Castle             12  00-1
# 2     3004              195    00-1  Weetabix Castle            115  00-1
# 3     3005               73    00-1  Weetabix Castle             57  00-1
# 4     3008               15    00-1  Weetabix Castle             18  00-1
#
#    Filled_Quantity
# 0               12
# 1               12
# 2              115
# 3               57
# 4               15

# %%
df_BOMs_grouped = df_BOMs.groupby('set_num')[['Filled_Quantity']].sum()

df_BOMs_grouped.sort_values(by='Filled_Quantity',ascending=False)
df_BOMs_grouped.reset_index(inplace=True)
print df_BOMs_grouped.shape
print len(df_BOMs_grouped.set_num.unique())
df_BOMs_grouped = pd.merge(df_BOMs_grouped,df_sets[['set_num','year','name']].drop_duplicates(), left_on='set_num',right_on='set_num', how='left')

df_BOMs_grouped[df_BOMs_grouped.year>2006].sort_values(by='Filled_Quantity',ascending=False).head(10)
# Out:
# (7370, 2)
# 7370
#       set_num  Filled_Quantity  year                    name
# 127   10188-1              597  2008              Death Star
# 5599  75159-1              564  2016              Death Star
# 5666  75827-1              556  2016  Firehouse Headquarters
# 155   10224-1              527  2012               Town Hall
# 206   10654-1              516  2016   XL Creative Brick Box
# 215   10664-1              516  2013          Creative Tower
# 246   10697-1              511  2015                XXXL Box
# 3565   5512-1              486  2010            LEGO XXL Box
# 3608   5589-1              486  2009               Giant Box
# 128   10189-1              485  2008               Taj Mahal

# %%
TOP_SETS = df_BOMs_grouped[df_BOMs_grouped.year>2006].nlargest(20,'Filled_Quantity')

# %%
TOP_SETS.head()
# Out:
#       set_num  Filled_Quantity  year                    name
# 127   10188-1              597  2008              Death Star
# 5599  75159-1              564  2016              Death Star
# 5666  75827-1              556  2016  Firehouse Headquarters
# 155   10224-1              527  2012               Town Hall
# 206   10654-1              516  2016   XL Creative Brick Box

# %%
TOP_SETS = ['10654-1']

# %% [markdown]
# ### Select on set and compute missing parts

# %% [markdown]
# ### Create a list of all possible 3 combinations

# %%
ALL_SETS_RECENTS = (df_sets[df_sets.year>2008]).set_num.unique()
len(ALL_SETS_RECENTS)
# Out:
# 4827

# %%
ALL_SETS_NO_TOPS = list(set(ALL_SETS_RECENTS)-set(TOP_SETS))

# %%
COMBI_SETS = list(itertools.product(TOP_SETS,ALL_SETS_NO_TOPS ))
print len(COMBI_SETS)
# Out:
# 4826

# %%
print len(COMBI_SETS)
print COMBI_SETS[0]
# Out:
# 4826
# ('10654-1', '30201-1')

# %%
def combine_sets(df_SETS_BOM,sets_list):
    df = df_SETS_BOM[df_SETS_BOM.set_num.isin(sets_list)] 
    df = df.groupby('part_num')[['quantity']].sum()
    return df.reset_index()

# %%
TOTAL_CASTLE_PARTS = df_6075_2_BOM.quantity.sum()
print TOTAL_CASTLE_PARTS
# Out:
# 676

# %%
def compute_combination_fullfillment_score(df_6075_2_BOM,df_set):
    df = pd.merge(df_6075_2_BOM,df_set, on='part_num',how='left',suffixes=['_6075_2','_sets'])
    df['Filled_Quantity']=df.quantity_6075_2-df.quantity_sets
    df.Filled_Quantity = np.where(df.Filled_Quantity<=0,df.quantity_6075_2,df.quantity_sets)
    df = df.fillna(0)
    
    return df.Filled_Quantity.sum()

# %%
from multiprocessing import Manager, Pool

manager = Manager()
shared_list = manager.list()

def do_stuff(x):
    global shared_list
    sets_num = [set_num for set_num in x]
    df_set = combine_sets(df_SETS,sets_num)
    score = compute_combination_fullfillment_score(df_6075_2_BOM,df_SETS)
    shared_list.append((sets_num,score))
    if len(shared_list)%1000==0:
        print len(shared_list)
    
pool = Pool(processes=10)
pool.map(do_stuff, COMBI_SETS)
pool.close()
# Out:
# 1000
# 2000
# 3000
# 4000

# %%
df_scores = pd.DataFrame([x for x in shared_list],columns=['sets','fullfilled_parts'])
df_sets = df_scores['sets'].apply(pd.Series)
df_sets.columns = ['set1', 'set2']
df_scores = pd.concat([df_scores,df_sets],axis=1)
#df_scores.drop(['sets'],axis=1,inplace=True)

# %%
df_scores.sort_values(by='fullfilled_parts',ascending=False)
# Out:
#                          sets  fullfilled_parts     set1          set2
# 0          [10654-1, 30201-1]            462664  10654-1       30201-1
# 3223       [10654-1, 40078-1]            462664  10654-1       40078-1
# 3221        [10654-1, 5762-1]            462664  10654-1        5762-1
# 3220       [10654-1, 76035-1]            462664  10654-1       76035-1
# 3219       [10654-1, 70779-1]            462664  10654-1       70779-1
# 3218        [10654-1, 8167-1]            462664  10654-1        8167-1
# 3217     [10654-1, 5001382-1]            462664  10654-1     5001382-1
# 3216     [10654-1, 2853302-1]            462664  10654-1     2853302-1
# 3215      [10654-1, 850457-1]            462664  10654-1      850457-1
# 3214       [10654-1, 30374-1]            462664  10654-1       30374-1
# 3213     [10654-1, 5001370-1]            462664  10654-1     5001370-1
# 3212       [10654-1, 66325-1]            462664  10654-1       66325-1
# 3211       [10654-1, 79015-1]            462664  10654-1       79015-1
# 3210        [10654-1, 9314-1]            462664  10654-1        9314-1
# 3209      [10654-1, 75056-15]            462664  10654-1      75056-15
# 3208        [10654-1, 7687-8]            462664  10654-1        7687-8
# 3207       [10654-1, 40019-1]            462664  10654-1       40019-1
# 3222       [10654-1, 75098-1]            462664  10654-1       75098-1
# 3224        [10654-1, 6743-1]            462664  10654-1        6743-1
# 3205       [10654-1, 70901-1]            462664  10654-1       70901-1
# 3225       [10654-1, 70780-1]            462664  10654-1       70780-1
# 3240       [10654-1, 76002-1]            462664  10654-1       76002-1
# 3239     [10654-1, 5004102-1]            462664  10654-1     5004102-1
# 3238       [10654-1, 9509-24]            462664  10654-1       9509-24
# 3237      [10654-1, 853130-1]            462664  10654-1      853130-1
# 3236  [10654-1, DKBATMANVD-1]            462664  10654-1  DKBATMANVD-1
# 3235        [10654-1, 9479-1]            462664  10654-1        9479-1
# 3234       [10654-1, 60022-1]            462664  10654-1       60022-1
# 3233        [10654-1, 6243-1]            462664  10654-1        6243-1
# 3232        [10654-1, 8982-1]            462664  10654-1        8982-1
# ...                       ...               ...      ...           ...
# 1596        [10654-1, 9498-1]            462664  10654-1        9498-1
# 1595        [10654-1, 8962-1]            462664  10654-1        8962-1
# 1594       [10654-1, 75160-1]            462664  10654-1       75160-1
# 1593        [10654-1, 7948-1]            462664  10654-1        7948-1
# 1592       [10654-1, 42027-1]            462664  10654-1       42027-1
# 1591       [10654-1, 70624-1]            462664  10654-1       70624-1
# 1590       [10654-1, 40009-1]            462664  10654-1       40009-1
# 1589        [10654-1, 6751-1]            462664  10654-1        6751-1
# 1588      [10654-1, 561407-1]            462664  10654-1      561407-1
# 1587        [10654-1, 8426-1]            462664  10654-1        8426-1
# 1586       [10654-1, 21018-1]            462664  10654-1       21018-1
# 1601       [10654-1, 10520-1]            462664  10654-1       10520-1
# 1602       [10654-1, 60145-1]            462664  10654-1       60145-1
# 1603       [10654-1, 75080-1]            462664  10654-1       75080-1
# 1612       [10654-1, 75137-1]            462664  10654-1       75137-1
# 1618        [10654-1, 4637-1]            462664  10654-1        4637-1
# 1617       [10654-1, 10618-1]            462664  10654-1       10618-1
# 1616       [10654-1, 71012-8]            462664  10654-1       71012-8
# 1615       [10654-1, 66448-1]            462664  10654-1       66448-1
# 1614       [10654-1, 70751-1]            462664  10654-1       70751-1
# 1613       [10654-1, 8683-16]            462664  10654-1       8683-16
# 1611       [10654-1, 75010-1]            462664  10654-1       75010-1
# 1604      [10654-1, 41040-16]            462664  10654-1      41040-16
# 1610     [10654-1, 5003564-1]            462664  10654-1     5003564-1
# 1609     [10654-1, 5000068-1]            462664  10654-1     5000068-1
# 1608        [10654-1, 5749-1]            462664  10654-1        5749-1
# 1607       [10654-1, 41132-1]            462664  10654-1       41132-1
# 1606     [10654-1, 2856453-1]            462664  10654-1     2856453-1
# 1605       [10654-1, 30601-1]            462664  10654-1       30601-1
# 4825     [10654-1, 5004752-1]            462664  10654-1     5004752-1
#
# [4826 rows x 4 columns]

# %%
df_sets = combine_sets(df_SETS_BOM,['10654-1','31044-1'])
df_matching = pd.merge(df_6075_2_BOM,df_sets,on='part_num',how='left',suffixes=['_6075_2','_10654_1'])
df_matching = pd.merge(df_matching,df_PARTS,on='part_num')
df_matching.quantity_10654_1.fillna(0,inplace=True)
df_matching['Missing_parts']=np.where((df_matching.quantity_6075_2-df_matching.quantity_10654_1)>0,df_matching.quantity_6075_2-df_matching.quantity_10654_1,0)
df_matching.sort_values(by='Missing_parts')
# Out:
#     part_num  quantity_6075_2  quantity_10654_1  \
# 10      3023               13              29.0
# 15      3039               12              44.0
# 37      3710                4              10.0
# 13      3034                2              10.0
# 12      3032                8               8.0
# 11      3024                8              17.0
# 27      3623                8               9.0
# 9       3022               18              28.0
# 8       3021                6               9.0
# 38      3795                8              10.0
# 6       3010               30              52.0
# 5       3009               29              32.0
# 4       3008               15              18.0
# 3       3005               73             180.0
# 2       3004              195             323.0
# 1       3003               16             266.0
# 16     3040b                2              36.0
# 31      3660               20              28.0
# 44     73037                1               0.0
# 41      3857                1               0.0
# 43  56823c50                1               0.0
# 20      3176                2               1.0
# 14      3036                1               0.0
# 24      3460                2               0.0
# 25      3581                2               0.0
# 28      3633                2               0.0
# 29      3644                2               0.0
# 21      3185                2               0.0
# 33      3673                2               0.0
# 7       3020               14              11.0
# 30      3659                3               0.0
# 42      3865                4               0.0
# 34      3684                6               2.0
# 35      3685                4               0.0
# 18     3069b                7               2.0
# 36      3700                5               0.0
# 39      3830                8               2.0
# 19     3087c                6               0.0
# 23      3308                6               0.0
# 17     3062a                6               0.0
# 40      3831                8               2.0
# 22      3307                8               0.0
# 0      3002a               12               0.0
# 26      3622               62              48.0
# 32      3665               32              13.0
#
#                                             name_part  part_cat_id  id  \
# 10                                        Plate 1 x 2           14  14
# 15                                    Slope 45° 2 x 2            3   3
# 37                                        Plate 1 x 4           14  14
# 13                                        Plate 2 x 8           14  14
# 12                                        Plate 4 x 6           14  14
# 11                                        Plate 1 x 1           14  14
# 27                                        Plate 1 x 3           14  14
# 9                                         Plate 2 x 2           14  14
# 8                                         Plate 2 x 3           14  14
# 38                                        Plate 2 x 6           14  14
# 6                                         Brick 1 x 4           11  11
# 5                                         Brick 1 x 6           11  11
# 4                                         Brick 1 x 8           11  11
# 3                                         Brick 1 x 1           11  11
# 2                                         Brick 1 x 2           11  11
# 1                                         Brick 2 x 2           11  11
# 16                    Slope 45° 2 x 1 with Bottom Pin            3   3
# 31  Slope Inverted 45° 2 x 2 [Ovoid Bottom Pin, Ba...            3   3
# 44      String Reel Winch 2 x 4 x 2 (Light Gray Drum)           31  31
# 41                                  Baseplate 16 x 32            1   1
# 43                              String Cord Thin 50cm           31  31
# 20                      Plate Special 3 x 2 with Hole            9   9
# 14                                        Plate 6 x 8           14  14
# 24                                        Plate 1 x 8           14  14
# 25        Brick Special 1 x 1 x 2 with Shutter Holder            5   5
# 28                                    Fence 1 x 4 x 1           32  32
# 29                                     Door 1 x 4 x 6           16  16
# 21                                    Fence 1 x 4 x 2           32  32
# 33     Technic Pin without Friction Ridges Lengthwise           53  53
# 7                                         Plate 2 x 4           14  14
# 30                                   Brick Arch 1 x 4           37  37
# 42                                   Baseplate 8 x 16            1   1
# 34                 Slope 75° 2 x 2 x 3 [Hollow Studs]            3   3
# 35                  Slope 75° 2 x 2 x 3 Double Convex            3   3
# 18                             Tile 1 x 2 with Groove           19  19
# 36                       Technic Brick 1 x 2 [1 Hole]            8   8
# 39                          Hinge Brick 1 x 4 [Upper]           18  18
# 19  Window 1 x 1 x 1 Classic with Short Sill, No G...           16  16
# 23                               Brick Arch 1 x 8 x 2           37  37
# 17                       Brick Round 1 x 1 Solid Stud           20  20
# 40                          Hinge Brick 1 x 4 [Lower]           18  18
# 22  Brick Arch 1 x 6 x 2 - Thick Top with Reinforc...           37  37
# 0                  Brick 2 x 3 without Cross Supports           11  11
# 26                                        Brick 1 x 3           11  11
# 32                           Slope Inverted 45° 2 x 1            3   3
#
#                        name_cat  Missing_parts
# 10                       Plates            0.0
# 15                Bricks Sloped            0.0
# 37                       Plates            0.0
# 13                       Plates            0.0
# 12                       Plates            0.0
# 11                       Plates            0.0
# 27                       Plates            0.0
# 9                        Plates            0.0
# 8                        Plates            0.0
# 38                       Plates            0.0
# 6                        Bricks            0.0
# 5                        Bricks            0.0
# 4                        Bricks            0.0
# 3                        Bricks            0.0
# 2                        Bricks            0.0
# 1                        Bricks            0.0
# 16                Bricks Sloped            0.0
# 31                Bricks Sloped            0.0
# 44      String, Bands and Reels            1.0
# 41                   Baseplates            1.0
# 43      String, Bands and Reels            1.0
# 20               Plates Special            1.0
# 14                       Plates            1.0
# 24                       Plates            2.0
# 25               Bricks Special            2.0
# 28     Bars, Ladders and Fences            2.0
# 29            Windows and Doors            2.0
# 21     Bars, Ladders and Fences            2.0
# 33                 Technic Pins            2.0
# 7                        Plates            3.0
# 30                Bricks Curved            3.0
# 42                   Baseplates            4.0
# 34                Bricks Sloped            4.0
# 35                Bricks Sloped            4.0
# 18                        Tiles            5.0
# 36               Technic Bricks            5.0
# 39  Hinges, Arms and Turntables            6.0
# 19            Windows and Doors            6.0
# 23                Bricks Curved            6.0
# 17       Bricks Round and Cones            6.0
# 40  Hinges, Arms and Turntables            6.0
# 22                Bricks Curved            8.0
# 0                        Bricks           12.0
# 26                       Bricks           14.0
# 32                Bricks Sloped           19.0
